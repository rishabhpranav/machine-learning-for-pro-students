# %%
import pandas as pd
import json
import urllib.request as url

# %%
http = url.urlopen("https://cricapi.com/api/matchCalendar?apikey=b7CYzlyYOrUCIIdbSlU753oGKN12")

# %%
data = json.load(http)

# %%
matches = data['data']

# %%
df = pd.DataFrame(matches)

# %%
df.head()
# Out:
#              date                                               name  \
# 0  18 August 2019  Sri Lanka v New Zealand at Galle, 1st Test - d...
# 1  18 August 2019    England v Australia at Lord's, 2nd Test - day 5
# 2  18 August 2019                Finland v Spain at Kerava, 3rd T20I
# 3  18 August 2019             Scotland v Oman at Aberdeen, 4th Match
# 4  18 August 2019  Bermuda v United States of America at  Sandys ...
#
#                              unique_id
# 0                              1192873
# 1                              1152847
# 2  will generate 1-2 days before match
# 3  will generate 1-2 days before match
# 4  will generate 1-2 days before match

# %%
pd.read_json('data.json')
# Out:
#     p_brand p_category  p_id  \
# 0     Apple     mobile   101
# 1   Samsung     mobile   102
# 2    Xiaomi     mobile   103
# 3     Apple     laptop   104
# 4      Asus     laptop   105
# 5     Titan      watch   106
# 6    Adidas      shoes   107
# 7      Puma      shoes   108
# 8       XYZ       book   109
# 9    Lenovo     laptop   110
# 10      JBL  headphone   111
# 11     Bose  headphone   112
#
#                                               p_image                  p_name  \
# 0   https://www.91-img.com/pictures/121008-v1-appl...          Apple Iphone X
# 1   https://www.boostmobile.com/content/dam/boostm...      Samsung Galaxy S10
# 2   https://www.91-img.com/pictures/125125-v3-xiao...            Redmi Note 5
# 3   https://cdn.shopify.com/s/files/1/0121/0014/11...             Macbook Pro
# 4   https://img-us1.asus.com/A/show/AW000706/2018/...          Asus Zenbook 2
# 5   http://assets.myntassets.com/assets/images/145...              Titan Plus
# ...
