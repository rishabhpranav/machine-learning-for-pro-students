# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(1,100)
y = x ** 2

# %%
plt.plot(x,y)

# %%
x1 = np.random.randn(100,2) * [-2,2]
x2 = np.random.randn(100,2) * [2,-2]

# %%
x = np.vstack((x1,x2))

# %%
x.shape
# Out:
# (200, 2)

# %%
plt.scatter(x1,x2)

# %%
y = np.zeros(200)

# %%
y[100:] = 1.0

# %%
plt.scatter(x[:,0],x[:,1],c=y)

# %%
plt.hist(x[:,0])
# Out:
# (array([ 6., 11., 22., 27., 35., 47., 29., 15.,  6.,  2.]),
#  array([-5.829962  , -4.67513665, -3.5203113 , -2.36548595, -1.21066061,
#         -0.05583526,  1.09899009,  2.25381544,  3.40864079,  4.56346614,
#          5.71829149]),
#  <a list of 10 Patch objects>)

# %%
x1 = np.random.randn(300,2) * [-2,2]
x2 = np.random.randn(300,2) * [2,-2]
x = np.vstack((x1,x2))

# %%
plt.hist(x[:,1])
plt.show()
